# %%
import torch
from torch.utils.data import DataLoader, Subset
from pathlib import Path
import cv2
import numpy as np
from tqdm import tqdm
from torchvision import transforms
from torchvision.models.detection import fasterrcnn_resnet50_fpn
from sklearn.metrics import roc_auc_score, log_loss, matthews_corrcoef, cohen_kappa_score

# %%
class MURADataset(torch.utils.data.Dataset):
    def __init__(self, img_dir, label_dir, transform=None):
        self.img_dir = Path(img_dir)
        self.label_dir = Path(label_dir)
        self.images = sorted(list(self.img_dir.glob("*.png")))
        self.transform = transform

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        img_path = self.images[idx]
        label_path = self.label_dir / (img_path.stem + ".txt")
        print(f"Loading image: {img_path}")  # Debug (comment out if not needed)
        img = cv2.imread(str(img_path))
        if img is None:
            print(f"Failed to load image: {img_path}")
            return None
        
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        
        try:
            with open(label_path, "r") as f:
                line = f.readline().strip().split()
                if not line:
                    print(f"No label data for: {label_path}")
                    return None
                class_id, x, y, w, h = map(float, line)
                x_min = (x - w/2) * 300
                y_min = (y - h/2) * 300
                x_max = (x + w/2) * 300
                y_max = (y + h/2) * 300
                if x_max <= x_min or y_max <= y_min:
                    print(f"Invalid box for: {label_path}")
                    return None
                target = {
                    "boxes": torch.tensor([[x_min, y_min, x_max, y_max]], dtype=torch.float32),
                    "labels": torch.tensor([int(class_id)], dtype=torch.int64)
                }
        except Exception as e:
            print(f"Error processing label {label_path}: {e}")
            return None

        if self.transform:
            img = self.transform(img)
        
        return img, target

# %%
device = torch.device("cuda")
if not torch.cuda.is_available():
    raise RuntimeError("CUDA is not available. This code requires a GPU.")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
transform = transforms.Compose([
    transforms.ToPILImage(),
    transforms.Resize((300, 300)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

train_dataset = MURADataset(
    "D:/Sem 6 project/MURA_YOLO/train/images",
    "D:/Sem 6 project/MURA_YOLO/train/labels",
    transform=transform
)

filtered_indices = []
for idx in range(len(train_dataset)):
    try:
        item = train_dataset[idx]
        if item is not None:
            filtered_indices.append(idx)
    except Exception:
        pass

train_dataset = Subset(train_dataset, filtered_indices)
# train_dataset = Subset(train_dataset, range(100))  # Uncomment to test with 100 samples

valid_dataset = MURADataset(
    "D:/Sem 6 project/MURA_YOLO/valid/images",
    "D:/Sem 6 project/MURA_YOLO/valid/labels",
    transform=transform
)

filtered_indices = []
for idx in range(len(valid_dataset)):
    try:
        item = valid_dataset[idx]
        if item is not None:
            filtered_indices.append(idx)
    except Exception:
        pass

valid_dataset = Subset(valid_dataset, filtered_indices)
# Out:
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image10.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image11.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10000.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10003.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10006.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10009.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_1001.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10012.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10016.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10019.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10022.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10025.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10028.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_1003.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10031.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10034.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10037.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10040.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10043.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10046.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10049.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10052.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10055.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10058.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10061.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10065.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10068.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_1007.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10070.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10073.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10075.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10078.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10079.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10080.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10083.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10086.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10089.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10092.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10096.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10097.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10100.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10103.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10106.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10109.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_1011.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10112.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10115.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10118.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10122.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10125.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10128.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10131.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10134.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10138.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10141.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10144.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10147.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_1015.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10150.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10153.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10155.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10158.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10161.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10164.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10167.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_1017.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10170.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10173.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10175.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10178.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10181.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10184.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10185.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10187.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10192.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10195.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10198.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_102.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_1020.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10201.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10204.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10208.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10211.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10215.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10218.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10221.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10224.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10227.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10230.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10233.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10236.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10239.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_1024.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10242.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10245.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10248.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10251.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10256.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10259.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10262.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10265.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10268.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10271.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10274.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10277.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10279.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10282.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10285.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10288.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_1029.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10290.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10292.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10296.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10299.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10303.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10306.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10309.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10312.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10315.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10318.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10321.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10324.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10327.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_1033.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10330.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10333.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10336.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10339.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_1034.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10342.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10345.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10348.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10352.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10355.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10358.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10361.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10364.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10367.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10369.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10372.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10375.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10378.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_1038.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10381.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10384.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10387.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10391.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10394.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10397.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10400.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10404.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10406.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10409.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10412.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10415.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10418.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_1042.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10421.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10424.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10427.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10430.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10433.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10437.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10440.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10443.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10446.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_1045.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10450.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10453.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10454.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10455.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10458.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10461.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10465.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10468.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10471.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10474.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10477.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_1048.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10480.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10483.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10484.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10487.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10490.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10493.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10496.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10499.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_105.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_1050.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10501.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10505.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10508.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10511.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10514.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10517.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10520.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10523.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10526.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10529.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10531.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10534.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10537.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_1054.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10540.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10543.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10547.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10548.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10551.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10554.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10557.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10560.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10563.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10566.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10569.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_1057.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10572.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10575.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10578.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10582.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10585.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10588.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10591.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10592.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10595.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10598.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_1060.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10601.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10604.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10607.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10610.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10613.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10617.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10620.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10623.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10626.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10629.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10632.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10635.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10638.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_1064.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10641.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10644.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10647.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10650.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10652.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10655.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10658.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_1066.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10661.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10664.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10667.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10669.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10673.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10675.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10678.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10683.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10687.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10691.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10694.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10697.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_1070.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10700.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10703.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10706.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10710.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10713.png
# Failed to load image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10713.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10716.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10719.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10722.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10725.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10729.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_1073.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10732.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10735.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10738.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10741.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10744.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10748.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10751.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10755.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10758.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10761.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10764.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10767.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_1077.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10770.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10773.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10776.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10779.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10782.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10783.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10786.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10789.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10793.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10794.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10797.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_108.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_1080.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10800.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10803.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10804.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10807.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10810.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10813.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10816.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10819.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10822.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10825.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10828.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10831.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10834.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10837.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_1084.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10840.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10843.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10846.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10849.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10852.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10853.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10856.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10859.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_1086.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10862.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10865.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10869.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10872.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10876.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10878.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10881.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10884.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10887.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10890.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10893.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10898.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_1090.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10901.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10904.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10907.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10910.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10913.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10917.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_1092.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10920.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10923.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10926.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10930.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10933.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10936.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10939.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10942.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10946.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10949.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_1095.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10952.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10955.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10958.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10962.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10965.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10968.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10971.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10974.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10977.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_1098.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10980.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10983.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10986.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10990.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10993.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10995.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_10998.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_1100.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11001.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11004.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11008.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11011.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11014.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11015.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11018.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_1102.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11021.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11024.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11027.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_1103.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11030.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11033.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11036.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11039.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11042.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11045.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11048.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_1105.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11051.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11054.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11058.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11061.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11064.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11065.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11068.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11072.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11073.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11076.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11079.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11082.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11085.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11088.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_1109.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11091.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11094.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11097.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_111.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11100.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11103.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11106.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11109.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11112.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11115.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11118.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11121.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11124.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11127.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_1113.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11130.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11133.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11136.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11139.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11142.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11145.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11148.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11149.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_1115.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11152.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11156.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11159.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11162.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11165.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11167.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11170.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11173.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11176.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11179.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_1118.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11182.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11185.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11188.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11191.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11194.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11197.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_1120.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11200.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11204.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11207.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11210.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11213.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11216.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11219.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11222.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11225.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11228.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_1123.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11231.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11234.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11237.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11238.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11241.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11245.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11248.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11251.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11254.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11257.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11259.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11262.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11265.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11268.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_1127.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11271.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11274.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11277.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11280.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11284.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11287.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11289.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11292.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11295.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11298.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11301.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11304.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11306.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11309.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11313.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11317.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_1132.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11320.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11323.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11326.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11329.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11332.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11335.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11339.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11342.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11343.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11346.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11349.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11352.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11355.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11358.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_1136.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11360.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11362.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11365.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11368.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11371.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11374.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11377.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11380.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11381.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11384.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11387.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11391.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11394.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11398.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_1140.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11402.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11405.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11409.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11412.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11415.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11418.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_1142.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11421.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11424.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11427.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11430.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11433.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11435.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11438.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11442.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11445.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11448.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11452.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11455.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11458.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_1146.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11461.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11464.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11466.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11469.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11472.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11475.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11478.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11481.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11484.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11487.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11490.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11493.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11496.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11499.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_1150.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11502.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11505.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11508.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11511.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11514.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11517.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11520.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11523.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11526.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11529.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_1153.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11532.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11535.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11538.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_1154.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11542.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11543.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11546.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11549.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11552.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11555.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11558.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11561.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11563.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11566.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11569.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_1157.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11572.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11575.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11578.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11581.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11584.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11587.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11591.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11594.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11597.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_116.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_1160.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11600.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11603.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11607.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11610.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11613.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11616.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11619.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_1162.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11622.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11626.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11630.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11633.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11636.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11639.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11642.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11643.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11646.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11649.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11652.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11655.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11658.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_1166.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11661.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11662.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11665.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11666.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11670.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11673.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11676.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11679.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_1168.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11682.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11685.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11688.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11691.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11692.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11695.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11698.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11701.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11704.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11705.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11708.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11709.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_1171.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11710.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11713.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11714.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11717.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11720.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11721.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11724.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11727.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11729.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_1173.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11732.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11736.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11739.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11742.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11745.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11746.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11749.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11752.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11755.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11758.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_1176.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11761.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11764.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11767.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11768.png
# Loading image: D:\Sem 6 project\MURA_YOLO\train\images\image1_11769.png
# ...
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image3_96.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image3_962.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image3_965.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image3_968.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image3_971.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image3_975.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image3_978.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image3_982.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image3_987.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image3_99.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image3_990.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image3_993.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image3_999.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_1003.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_1069.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_107.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_1133.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_118.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_131.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_1312.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_137.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_1556.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_16.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_1602.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_1625.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_1639.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_1653.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_170.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_1716.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_1723.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_1735.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_174.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_1743.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_1747.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_1757.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_1775.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_1795.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_1802.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_1811.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_1820.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_1824.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_1831.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_1835.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_184.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_1846.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_1850.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_1860.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_1865.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_1871.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_1878.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_1882.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_1886.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_1900.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_1907.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_1914.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_1926.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_1931.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_1937.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_1946.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_1960.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_1964.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_1973.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_1996.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_2018.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_2031.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_2049.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_2053.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_2060.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_2065.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_207.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_2092.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_2105.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_2112.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_2116.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_2120.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_2124.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_2133.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_2138.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_2152.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_2170.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_2178.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_2187.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_2200.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_2213.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_2220.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_2227.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_2231.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_2249.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_2253.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_226.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_2267.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_2277.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_2282.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_2286.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_2290.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_2296.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_2306.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_232.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_2320.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_2324.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_2332.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_2341.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_2345.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_2351.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_2359.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_236.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_2366.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_2380.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_2385.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_2392.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_2400.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_2407.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_2421.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_2426.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_2432.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_2444.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_245.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_2455.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_2462.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_2472.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_2483.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_2487.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_2492.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_2500.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_2526.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_2562.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_2583.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_2610.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_2616.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_2639.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_2643.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_2650.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_2661.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_2665.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_268.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_2681.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_2710.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_2720.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_2757.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_2804.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_2826.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_2847.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_285.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_2867.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_2880.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_2887.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_2943.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_2947.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_2985.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_2989.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_3037.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_304.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_3193.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_322.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_326.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_33.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_346.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_350.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_399.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_40.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_412.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_457.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_464.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_502.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_542.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_564.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_598.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_616.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_622.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_640.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_655.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_72.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_726.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_738.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_748.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_793.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_908.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_937.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_972.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_979.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image4_994.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image5.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image5_1004.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image5_1557.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image5_1758.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image5_185.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image5_1887.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image5_1908.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image5_1927.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image5_1974.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image5_2134.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image5_2278.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image5_2297.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image5_2307.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image5_2346.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image5_2352.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image5_2367.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image5_2381.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image5_2386.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image5_2393.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image5_2401.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image5_2408.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image5_2422.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image5_2433.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image5_2445.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image5_2456.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image5_2473.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image5_2488.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image5_2493.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image5_2501.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image5_2888.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image5_503.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image5_617.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image5_794.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image5_909.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image6.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image6_2347.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image6_2446.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image6_2457.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image7.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image7_2447.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image7_2458.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image8.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image8_2448.png
# Loading image: D:\Sem 6 project\MURA_YOLO\valid\images\image9.png

# %%
def custom_collate(batch):
    batch = [item for item in batch if item is not None]
    if not batch:
        return [], []
    images = [item[0] for item in batch]
    targets = [item[1] for item in batch]
    return images, targets

train_loader = DataLoader(
    train_dataset,
    batch_size=4,
    shuffle=True,
    num_workers=2,
    collate_fn=custom_collate,
    pin_memory=True
)

valid_loader = DataLoader(
    valid_dataset,
    batch_size=4,
    shuffle=False,
    num_workers=2,
    collate_fn=custom_collate,
    pin_memory=True
)

model = fasterrcnn_resnet50_fpn(num_classes=15, weights=None)
model = model.to(device)

# %%
checkpoint_dir = Path("D:/Sem 6 project/checkpoints")
checkpoint_dir.mkdir(exist_ok=True)

start_epoch = 0
latest_checkpoint_path = checkpoint_dir / "latest_faster_rcnn_checkpoint.pt"

if latest_checkpoint_path.exists():
    checkpoint = torch.load(latest_checkpoint_path, map_location=device)
    model.load_state_dict(checkpoint['model_state_dict'])
    start_epoch = checkpoint['epoch'] + 1
    print(f"Resuming from epoch {start_epoch}")
else:
    print("No checkpoint found, starting from scratch")

num_epochs = 25
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

for epoch in range(start_epoch, num_epochs):
    print(f"\nEpoch {epoch+1}/{num_epochs}")
    model.train()
    total_loss = 0
    batch_count = 0
    
    with tqdm(total=len(train_loader), desc=f"Epoch {epoch+1}/{num_epochs}") as pbar:
        for batch_idx, (images, targets) in enumerate(train_loader):
            if not images:
                pbar.update(1)
                continue
            
            images = [img.to(device) for img in images]
            targets = [{k: v.to(device) for k, v in t.items()} for t in targets]
            
            try:
                loss_dict = model(images, targets)
                losses = sum(loss_dict.values())
                
                optimizer.zero_grad()
                losses.backward()
                optimizer.step()
            except RuntimeError as e:
                print(f"Error in batch {batch_idx+1}: {e}")
                torch.cuda.empty_cache()
                continue
            
            current_mem = torch.cuda.memory_allocated(device) / 1e9
            total_mem = torch.cuda.get_device_properties(device).total_memory / 1e9
            mem_str = f"{current_mem:.2f}/{total_mem:.2f}GB"
            
            total_loss += losses.item()
            batch_count += 1
            
            pbar.set_postfix({
                'loss': f"{losses.item():.4f}",
                'mem': mem_str
            })
            pbar.update(1)
    
    avg_loss = total_loss / batch_count if batch_count > 0 else 0
    print(f"Epoch {epoch+1}/{num_epochs}, Avg Loss: {avg_loss:.4f}")
    
    checkpoint_path = checkpoint_dir / f"faster_rcnn_resnet50_mura_epoch{epoch+1}.pt"
    torch.save({
        'epoch': epoch,
        'model_state_dict': model.state_dict(),
        'optimizer_state_dict': optimizer.state_dict(),
    }, checkpoint_path)
    print(f"Saved checkpoint: {checkpoint_path}")
    
    torch.save({
        'epoch': epoch,
        'model_state_dict': model.state_dict(),
        'optimizer_state_dict': optimizer.state_dict(),
    }, latest_checkpoint_path)
    print(f"Saved latest checkpoint: {latest_checkpoint_path}")
# Out:
# No checkpoint found, starting from scratch
#
# Epoch 1/25
# Epoch 1/25:   0%|                                                                             | 0/9202 [00:00<?, ?it/s]

# %%
if latest_checkpoint_path.exists():
    checkpoint = torch.load(latest_checkpoint_path, map_location=device)
    model.load_state_dict(checkpoint['model_state_dict'])
    print(f"Loaded model from {latest_checkpoint_path} for evaluation")
else:
    print("No checkpoint found for evaluation. Using current model state.")

def evaluate(model, data_loader, device, desc="Evaluating"):
    model.eval()
    total_accuracy = 0
    batch_count = 0
    all_preds = []
    all_targets = []
    all_scores = []
    total_log_loss = 0

    with torch.no_grad():
        with tqdm(total=len(data_loader), desc=desc) as pbar:
            for batch_idx, (images, targets) in enumerate(data_loader):
                if not images or len(images) != len(targets):
                    pbar.update(1)
                    continue

                try:
                    images = [img.to(device) for img in images]
                    targets = [{k: v.to(device) for k, v in t.items()} for t in targets]

                    preds = model(images)

                    batch_accuracy = 0
                    batch_preds = []
                    batch_targets = []
                    batch_scores = []
                    for pred, target in zip(preds, targets):
                        pred_labels = pred['labels']
                        pred_scores = pred['scores']
                        gt_labels = target['labels']
                        if len(pred_labels) > 0:
                            max_score_idx = torch.argmax(pred_scores)
                            pred_label = pred_labels[max_score_idx].item()
                            pred_score = pred_scores[max_score_idx].item()
                            correct = 1.0 if (pred_label == gt_labels[0].item()) else 0.0
                            batch_accuracy += correct
                        else:
                            pred_label = 0
                            pred_score = 0.0
                            batch_accuracy += 0
                        batch_preds.append(pred_label)
                        batch_targets.append(gt_labels[0].item())
                        batch_scores.append(pred_score)

                    batch_accuracy /= len(targets) if len(targets) > 0 else 1

                    binary_targets = [1 if t > 0 else 0 for t in batch_targets]
                    binary_probs = torch.sigmoid(torch.tensor(batch_scores)).cpu().numpy()
                    binary_probs_2d = np.vstack([1 - binary_probs, binary_probs]).T
                    batch_log_loss = log_loss(binary_targets, binary_probs_2d, labels=[0, 1])
                    total_log_loss += batch_log_loss

                    all_preds.extend(batch_preds)
                    all_targets.extend(batch_targets)
                    all_scores.extend(batch_scores)

                    total_accuracy += batch_accuracy
                    batch_count += 1

                    pbar.set_postfix({'acc': f"{batch_accuracy:.4f}"})
                    pbar.update(1)
                except RuntimeError as e:
                    print(f"Evaluation error in batch {batch_idx+1}: {e}")
                    torch.cuda.empty_cache()

    avg_accuracy = total_accuracy / batch_count if batch_count > 0 else 0
    avg_log_loss = total_log_loss / batch_count if batch_count > 0 else 0

    all_preds = np.array(all_preds)
    all_targets = np.array(all_targets)
    all_scores = np.array(all_scores)

    true_positives = np.sum((all_preds > 0) & (all_targets > 0))
    true_negatives = np.sum((all_preds == 0) & (all_targets == 0))
    false_positives = np.sum((all_preds > 0) & (all_targets == 0))
    false_negatives = np.sum((all_preds == 0) & (all_targets > 0))

    precision = true_positives / (true_positives + false_positives) if (true_positives + false_positives) > 0 else 0
    recall = true_positives / (true_positives + false_negatives) if (true_positives + false_negatives) > 0 else 0
    f1 = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0

    specificity = true_negatives / (true_negatives + false_positives) if (true_negatives + false_positives) > 0 else 0
    g_mean = np.sqrt(recall * specificity) if (recall * specificity) > 0 else 0

    binary_targets = (all_targets > 0).astype(int)
    auc = roc_auc_score(binary_targets, all_scores) if len(np.unique(binary_targets)) > 1 else 0

    mcc = matthews_corrcoef(all_targets, all_preds)
    kappa = cohen_kappa_score(all_targets, all_preds)

    return {
        "precision": precision,
        "recall": recall,
        "f1": f1,
        "accuracy": avg_accuracy,
        "specificity": specificity,
        "g_mean": g_mean,
        "auc": auc,
        "mcc": mcc,
        "kappa": kappa,
        "log_loss": avg_log_loss
    }

print("\nEvaluating on Training Set:")
train_metrics = evaluate(model, train_loader, device, desc="Eval on Train")
print("Train Evaluation Metrics:")
print(f"1. Precision: {train_metrics['precision']:.4f}")
print(f"2. Recall: {train_metrics['recall']:.4f}")
print(f"3. F1 Score: {train_metrics['f1']:.4f}")
print(f"4. Accuracy: {train_metrics['accuracy']:.4f}")
print(f"5. Specificity: {train_metrics['specificity']:.4f}")
print(f"6. G-Mean: {train_metrics['g_mean']:.4f}")
print(f"7. AUC (ROC-AUC): {train_metrics['auc']:.4f}")
print(f"8. MCC: {train_metrics['mcc']:.4f}")
print(f"9. Cohen's Kappa: {train_metrics['kappa']:.4f}")
print(f"10. Log Loss: {train_metrics['log_loss']:.4f}")

print("\nEvaluating on Validation Set:")
valid_metrics = evaluate(model, valid_loader, device, desc="Eval on Valid")
print("Validation Evaluation Metrics:")
print(f"1. Precision: {valid_metrics['precision']:.4f}")
print(f"2. Recall: {valid_metrics['recall']:.4f}")
print(f"3. F1 Score: {valid_metrics['f1']:.4f}")
print(f"4. Accuracy: {valid_metrics['accuracy']:.4f}")
print(f"5. Specificity: {valid_metrics['specificity']:.4f}")
print(f"6. G-Mean: {valid_metrics['g_mean']:.4f}")
print(f"7. AUC (ROC-AUC): {valid_metrics['auc']:.4f}")
print(f"8. MCC: {valid_metrics['mcc']:.4f}")
print(f"9. Cohen's Kappa: {valid_metrics['kappa']:.4f}")
print(f"10. Log Loss: {valid_metrics['log_loss']:.4f}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 if latest_checkpoint_path.exists():
#       2     checkpoint = torch.load(latest_checkpoint_path, map_location=device)
#       3     model.load_state_dict(checkpoint['model_state_dict'])
#
# NameError: name 'latest_checkpoint_path' is not defined
